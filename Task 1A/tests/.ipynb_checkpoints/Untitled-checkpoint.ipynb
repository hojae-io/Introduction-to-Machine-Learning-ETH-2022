# %%
c = [5.393854890919694, 5.391582198581079, 5.388408650389066, 5.389427853158584, 5.388177739084459, 5.38869276086308, 5.388505524021711, 5.388697402621321, 5.388775957227663, 5.388400479662549, 5.388897102357417]
d = [(i+1)*1000 for i in range(len(c))]
print(c[-2]-c[-1])
import matplotlib.pyplot as plt
plt.plot(d,c)
plt.show()
# Out:
# 4.673249341280439e-05
