# %%
import pandas as pd
task2 = pd.read_csv("y_task2.csv")

# %%
task2
# Out:
#        LABEL_Sepsis
# 0          0.010459
# 1          0.001538
# 2          0.001333
# 3          0.003667
# 4          0.002429
# ...             ...
# 12659      0.001424
# 12660      0.001997
# 12661      0.004092
# 12662      0.002792
# 12663      0.001738
#
# [12664 rows x 1 columns]

# %%
task3 = pd.read_csv("y_task3.csv")

# %%
task3
# Out:
#        LABEL_RRate  LABEL_ABPm  LABEL_SpO2  LABEL_Heartrate
# 0        16.587936   84.061050   98.831290        86.616088
# 1        17.852835   86.517402   97.432785        90.200357
# 2        18.953483   73.590349   95.557363        69.400579
# 3        16.522814   89.934676   98.113115        91.377605
# 4        18.643589   90.765926   96.649855        89.913472
# ...            ...         ...         ...              ...
# 12659    17.312794   73.648424   96.983956        70.015875
# 12660    16.381503   82.533943   96.761890        91.403075
# 12661    18.379722   72.551383   97.942238        92.024140
# 12662    18.291592   90.234583   97.312935       109.956853
# 12663    16.716696   83.066163   98.661628       102.962495
#
# [12664 rows x 4 columns]

# %%
task2_3 = pd.concat([task2, task3], axis=1)
pids = pd.read_csv("pids.csv")

# %%
task2_3
# Out:
#        LABEL_Sepsis  LABEL_RRate  LABEL_ABPm  LABEL_SpO2  LABEL_Heartrate
# 0          0.010459    16.587936   84.061050   98.831290        86.616088
# 1          0.001538    17.852835   86.517402   97.432785        90.200357
# 2          0.001333    18.953483   73.590349   95.557363        69.400579
# 3          0.003667    16.522814   89.934676   98.113115        91.377605
# 4          0.002429    18.643589   90.765926   96.649855        89.913472
# ...             ...          ...         ...         ...              ...
# 12659      0.001424    17.312794   73.648424   96.983956        70.015875
# 12660      0.001997    16.381503   82.533943   96.761890        91.403075
# 12661      0.004092    18.379722   72.551383   97.942238        92.024140
# 12662      0.002792    18.291592   90.234583   97.312935       109.956853
# 12663      0.001738    16.716696   83.066163   98.661628       102.962495
#
# [12664 rows x 5 columns]

# %%
pids
# Out:
#          pid
# 0          0
# 1          3
# 2          5
# 3          7
# 4          9
# ...      ...
# 12659  31647
# 12660  31649
# 12661  31651
# 12662  31652
# 12663  31655
#
# [12664 rows x 1 columns]

# %%
task2_3_pids = pd.concat([pids, task2_3], axis=1)

# %%
task2_3_pids
# Out:
#          pid  LABEL_Sepsis  LABEL_RRate  LABEL_ABPm  LABEL_SpO2  \
# 0          0      0.010459    16.587936   84.061050   98.831290
# 1          3      0.001538    17.852835   86.517402   97.432785
# 2          5      0.001333    18.953483   73.590349   95.557363
# 3          7      0.003667    16.522814   89.934676   98.113115
# 4          9      0.002429    18.643589   90.765926   96.649855
# ...      ...           ...          ...         ...         ...
# 12659  31647      0.001424    17.312794   73.648424   96.983956
# 12660  31649      0.001997    16.381503   82.533943   96.761890
# 12661  31651      0.004092    18.379722   72.551383   97.942238
# 12662  31652      0.002792    18.291592   90.234583   97.312935
# 12663  31655      0.001738    16.716696   83.066163   98.661628
#
#        LABEL_Heartrate
# 0            86.616088
# 1            90.200357
# 2            69.400579
# 3            91.377605
# 4            89.913472
# ...                ...
# 12659        70.015875
# ...

# %%
task1 = pd.read_csv("y_task1.csv")
task1
# Out:
#          pid  LABEL_BaseExcess  LABEL_Fibrinogen  LABEL_AST  \
# 0          0             0.724             0.903      0.479
# 1      10001             0.141             0.574      0.125
# 2      10003             0.073             0.384      0.174
# 3      10004             0.130             0.415      0.272
# 4      10005             0.138             0.279      0.112
# ...      ...               ...               ...        ...
# 12659   9989             0.071             0.415      0.142
# 12660   9991             0.707             0.540      0.136
# 12661   9992             0.344             0.477      0.127
# 12662   9994             0.867             0.929      0.959
# 12663   9997             0.839             0.574      0.125
#
#        LABEL_Alkalinephos  LABEL_Bilirubin_total  LABEL_Lactate  \
# 0                   0.928                  0.935          0.361
# 1                   0.466                  0.131          0.232
# ...

# %%
fin = pd.merge(task1, task2_3_pids, on="pid")

# %%
fin
# Out:
#          pid  LABEL_BaseExcess  LABEL_Fibrinogen  LABEL_AST  \
# 0          0             0.724             0.903      0.479
# 1      10001             0.141             0.574      0.125
# 2      10003             0.073             0.384      0.174
# 3      10004             0.130             0.415      0.272
# 4      10005             0.138             0.279      0.112
# ...      ...               ...               ...        ...
# 12659   9989             0.071             0.415      0.142
# 12660   9991             0.707             0.540      0.136
# 12661   9992             0.344             0.477      0.127
# 12662   9994             0.867             0.929      0.959
# 12663   9997             0.839             0.574      0.125
#
#        LABEL_Alkalinephos  LABEL_Bilirubin_total  LABEL_Lactate  \
# 0                   0.928                  0.935          0.361
# 1                   0.466                  0.131          0.232
# ...

# %%
task2_3_pids[task2_3_pids['pid'] == 10001]
# Out:
#         pid  LABEL_Sepsis  LABEL_RRate  LABEL_ABPm  LABEL_SpO2  \
# 3968  10001      0.002268    18.152602   88.083877   94.477135
#
#       LABEL_Heartrate
# 3968        95.949015

# %%
compression_opts = dict(method='zip', archive_name='prediction.csv') # finally saving and compressing the predicted results
fin.to_csv('prediction.zip', index=False, float_format='%.3f',compression=compression_opts)
